# %%
print("Hola TechMind")
# Out:
# Hola TechMind

# %%
import pandas as pd
from pathlib import Path

# %%
PROJECT_ROOT = Path.cwd().parent

DATA_PATH = (
    PROJECT_ROOT
    / "data"
    / "processed"
    / "dataset.csv"
)

df = pd.read_csv(DATA_PATH)

print("Dataset cargado correctamente")
print("Filas:", df.shape[0])
print("Columnas:", df.shape[1])
# Out:
# Dataset cargado correctamente
# Filas: 301
# Columnas: 3

# %%
df["categoria"].value_counts()
# Out:
# categoria
# Bases de Datos      72
# Cloud               69
# Machine Learning    37
# Backend             35
# Frontend            27
# Data Science        27
# Cybersecurity       21
# DevOps              13
# Name: count, dtype: int64

# %% [markdown]
# verificar la calidad básica

# %%
print("Valores nulos:")
print(df.isnull().sum())

print("\nDuplicados completos:")
print(df.duplicated().sum())

print("\nTextos duplicados:")
print(df["texto"].duplicated().sum())
# Out:
# Valores nulos:
# titulo       0
# texto        0
# categoria    0
# dtype: int64
#
# Duplicados completos:
# 0
#
# Textos duplicados:
# 0

# %%
category_counts = df["categoria"].value_counts()

print(category_counts)
# Out:
# categoria
# Bases de Datos      72
# Cloud               69
# Machine Learning    37
# Backend             35
# Frontend            27
# Data Science        27
# Cybersecurity       21
# DevOps              13
# Name: count, dtype: int64

# %%
category_percentages = (
    df["categoria"]
    .value_counts(normalize=True)
    .mul(100)
    .round(2)
)

print(category_percentages)
# Out:
# categoria
# Bases de Datos      23.92
# Cloud               22.92
# Machine Learning    12.29
# Backend             11.63
# Frontend             8.97
# Data Science         8.97
# Cybersecurity        6.98
# DevOps               4.32
# Name: proportion, dtype: float64

# %% [markdown]
# Medir las categorias formalmente

# %%
print(
    "Mayor categoría:",
    category_counts.max()
)

print(
    "Menor categoría:",
    category_counts.min()
)

print(
    "Relación máximo/mínimo:",
    round(
        category_counts.max()
        / category_counts.min(),
        2
    )
)
# Out:
# Mayor categoría: 72
# Menor categoría: 13
# Relación máximo/mínimo: 5.54

# %% [markdown]
# Analizaremos la longitud del contenido

# %%
df["longitud_texto"] = (
    df["texto"]
    .astype(str)
    .str.len()
)

df["longitud_texto"].describe()
# Out:
# count     301.000000
# mean     1820.853821
# std       404.315865
# min       324.000000
# 25%      1988.000000
# 50%      1995.000000
# 75%      1997.000000
# max      1999.000000
# Name: longitud_texto, dtype: float64

# %%
df.groupby("categoria")["longitud_texto"].agg(
    ["count", "mean", "median", "min", "max"]
).round(2)
# Out:
#                   count     mean  median  min   max
# categoria
# Backend              35  1841.71  1995.0  438  1999
# Bases de Datos       72  1830.67  1995.0  659  1999
# Cloud                69  1904.51  1996.0  324  1999
# Cybersecurity        21  1694.86  1995.0  484  1999
# Data Science         27  1721.96  1990.0  410  1999
# DevOps               13  1655.62  1992.0  724  1999
# Frontend             27  1734.00  1993.0  424  1999
# Machine Learning     37  1891.14  1996.0  722  1999

# %% [markdown]
# el proceso de recolección está aplicando un límite de aproximadamente 2,000 caracteres.

# %% [markdown]
# Gráfico 1: distribución por categoría

# %%
import matplotlib.pyplot as plt

df["categoria"].value_counts().sort_values().plot(
    kind="barh",
    figsize=(10, 6)
)

plt.title("Distribución de registros por categoría")
plt.xlabel("Número de registros")
plt.ylabel("Categoría")
plt.tight_layout()
plt.show()

# %% [markdown]
# Gráfico 2: número de tecnologías por categoría.

# %%
tecnologias_categoria = (
    df.groupby("categoria")["tecnologia"]
    .nunique()
    .sort_values()
)

tecnologias_categoria.plot(
    kind="barh",
    figsize=(10, 6)
)

plt.title("Número de tecnologías por categoría")
plt.xlabel("Número de tecnologías")
plt.ylabel("Categoría")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 2
#       1 tecnologias_categoria = (
# ----> 2     df.groupby("categoria")["tecnologia"]
#       3     .nunique()
#       4     .sort_values()
#       5 )
#
# File C:\Proyectos\TechMind-DS\.venv\Lib\site-packages\pandas\core\groupby\generic.py:2938, in DataFrameGroupBy.__getitem__(self, key)
#    2931 if isinstance(key, tuple) and len(key) > 1:
#    2932     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    2933     # valid syntax, so don't raise
#    2934     raise ValueError(
#    2935         "Cannot subset columns with a tuple with more than one element. "
#    2936         "Use a list instead."
#    2937     )
# -> 2938 return super().__getitem__(key)
#
# File C:\Proyectos\TechMind-DS\.venv\Lib\site-packages\pandas\core\base.py:228, in SelectionMixin.__getitem__(self, key)
#     226 else:
#     227     if key not in self.obj:
# --> 228         raise KeyError(f"Column not found: {key}")
#     229     ndim = self.obj[key].ndim
#     230     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: tecnologia'

# %% [markdown]
# 3: distribución de la longitud de los textos

# %%
df["longitud_texto"].plot(
    kind="hist",
    bins=20,
    figsize=(10, 6)
)

plt.title("Distribución de la longitud de los textos")
plt.xlabel("Número de caracteres")
plt.ylabel("Frecuencia")
plt.tight_layout()
plt.show()

# %% [markdown]
# distribución de la longitud del texto por categoría.

# %%
plt.figure(figsize=(12, 6))

df.boxplot(
    column="longitud_texto",
    by="categoria",
    rot=45
)

plt.title("Distribución de longitud del texto por categoría")
plt.suptitle("")
plt.xlabel("Categoría")
plt.ylabel("Número de caracteres")
plt.tight_layout()
plt.show()

# %% [markdown]
# Ahora vamos a revisar el contenido real de los textos

# %%
df[
    ["titulo", "categoria", "longitud_texto"]
].head(20)
# Out:
#                                        titulo categoria  longitud_texto
# 0   FastAPI - FastAPI Official Docs - Parte 1   Backend            1996
# 1   FastAPI - FastAPI Official Docs - Parte 2   Backend            1997
# 2   FastAPI - FastAPI Official Docs - Parte 3   Backend            1993
# 3   FastAPI - FastAPI Official Docs - Parte 4   Backend            1995
# 4   FastAPI - FastAPI Official Docs - Parte 5   Backend            1996
# 5   FastAPI - FastAPI Official Docs - Parte 6   Backend            1999
# 6   FastAPI - FastAPI Official Docs - Parte 7   Backend            1997
# 7          FastAPI - FastAPI GitHub - Parte 1   Backend            1999
# 8          FastAPI - FastAPI GitHub - Parte 2   Backend            1988
# 9          FastAPI - FastAPI GitHub - Parte 3   Backend            1995
# 10         FastAPI - FastAPI GitHub - Parte 4   Backend            1998
# 11         FastAPI - FastAPI GitHub - Parte 5   Backend            1993
# 12         FastAPI - FastAPI GitHub - Parte 6   Backend            1992
# 13         FastAPI - FastAPI GitHub - Parte 7   Backend            1993
# 14         FastAPI - FastAPI GitHub - Parte 8   Backend            1194
# 15       FastAPI - FastAPI Tutorial - Parte 1   Backend            1988
# 16       FastAPI - FastAPI Tutorial - Parte 2   Backend            1998
# 17       FastAPI - FastAPI Tutorial - Parte 3   Backend             878
# 18    Django - Django Official Docs - Parte 1   Backend            1999
# 19    Django - Django Official Docs - Parte 2   Backend            1997

# %%
df[
    df["longitud_texto"] < 500
][
    ["titulo", "categoria", "texto", "longitud_texto"]
]
# Out:
#                                                 titulo      categoria  \
# 25                    Django - Django GitHub - Parte 3        Backend
# 48                    React - React Tutorial - Parte 7       Frontend
# 88      Scikit-learn - Scikit-learn Tutorial - Parte 7   Data Science
# 157  Oracle Cloud (OCI) - Oracle Cloud (OCI) Tutori...          Cloud
# 160                         AWS - AWS GitHub - Parte 3          Cloud
# 236                       NIST - NIST GitHub - Parte 3  Cybersecurity
#
#                                                  texto  longitud_texto
# 25   this page . https://www.djangoproject.com/fund...             438
# 48   onClick = { handleClick } /> < MyButton count ...             424
# 88   compatible inputs 13.2.5. Input and output arr...             410
# 157  YouTube channel . Additionally, visit educatio...             324
# 160  year of commit activity C# 128 Apache-2.0 888 ...             362
# 236  model for traction lithium battery recovery Uh...             484

# %% [markdown]
# contar por tecnologia

# %%
df["tecnologia"] = (
    df["titulo"]
    .str.split(" - ")
    .str[0]
)

df["tecnologia"].value_counts()
# Out:
# tecnologia
# Azure                 47
# Redis                 29
# PyTorch               25
# SQLite                24
# Oracle Cloud (OCI)    19
# FastAPI               18
# Django                14
# React                 14
# OWASP                 14
# Scikit-learn          13
# Pandas                 9
# MongoDB                9
# Vue                    8
# TensorFlow             7
# Angular                5
# NumPy                  5
# Hugging Face           5
# Docker                 5
# NIST                   5
# Kubernetes             4
# GitHub Actions         4
# PostgreSQL             4
# MariaDB                4
# NestJS                 3
# AWS                    3
# MySQL                  2
# Kali Linux             2
# Name: count, dtype: int64

# %%
df.groupby(
    ["categoria", "tecnologia"]
).size().sort_values(
    ascending=False
)
# Out:
# categoria         tecnologia
# Cloud             Azure                 47
# Bases de Datos    Redis                 29
# Machine Learning  PyTorch               25
# Bases de Datos    SQLite                24
# Cloud             Oracle Cloud (OCI)    19
# Backend           FastAPI               18
#                   Django                14
# Cybersecurity     OWASP                 14
# Frontend          React                 14
# Data Science      Scikit-learn          13
# Bases de Datos    MongoDB                9
# Data Science      Pandas                 9
# Frontend          Vue                    8
# Machine Learning  TensorFlow             7
# Frontend          Angular                5
# Machine Learning  Hugging Face           5
# DevOps            Docker                 5
# Cybersecurity     NIST                   5
# Data Science      NumPy                  5
# Bases de Datos    MariaDB                4
# DevOps            GitHub Actions         4
#                   Kubernetes             4
# Bases de Datos    PostgreSQL             4
# Backend           NestJS                 3
# Cloud             AWS                    3
# Bases de Datos    MySQL                  2
# Cybersecurity     Kali Linux             2
# dtype: int64

# %% [markdown]
# cuántos registros aporta cada tecnología a cada categoría

# %%
technology_category_table = pd.crosstab(
    df["tecnologia"],
    df["categoria"]
)

technology_category_table
# Out:
# categoria           Backend  Bases de Datos  Cloud  Cybersecurity  \
# tecnologia
# AWS                       0               0      3              0
# Angular                   0               0      0              0
# Azure                     0               0     47              0
# Django                   14               0      0              0
# Docker                    0               0      0              0
# FastAPI                  18               0      0              0
# GitHub Actions            0               0      0              0
# Hugging Face              0               0      0              0
# Kali Linux                0               0      0              2
# Kubernetes                0               0      0              0
# MariaDB                   0               4      0              0
# MongoDB                   0               9      0              0
# MySQL                     0               2      0              0
# NIST                      0               0      0              5
# NestJS                    3               0      0              0
# NumPy                     0               0      0              0
# OWASP                     0               0      0             14
# Oracle Cloud (OCI)        0               0     19              0
# Pandas                    0               0      0              0
# PostgreSQL                0               4      0              0
# PyTorch                   0               0      0              0
# React                     0               0      0              0
# Redis                     0              29      0              0
# SQLite                    0              24      0              0
# Scikit-learn              0               0      0              0
# TensorFlow                0               0      0              0
# Vue                       0               0      0              0
#
# categoria           Data Science  DevOps  Frontend  Machine Learning
# tecnologia
# AWS                            0       0         0                 0
# Angular                        0       0         5                 0
# Azure                          0       0         0                 0
# Django                         0       0         0                 0
# Docker                         0       5         0                 0
# FastAPI                        0       0         0                 0
# GitHub Actions                 0       4         0                 0
# Hugging Face                   0       0         0                 5
# Kali Linux                     0       0         0                 0
# Kubernetes                     0       4         0                 0
# MariaDB                        0       0         0                 0
# MongoDB                        0       0         0                 0
# MySQL                          0       0         0                 0
# NIST                           0       0         0                 0
# NestJS                         0       0         0                 0
# NumPy                          5       0         0                 0
# OWASP                          0       0         0                 0
# Oracle Cloud (OCI)             0       0         0                 0
# Pandas                         9       0         0                 0
# PostgreSQL                     0       0         0                 0
# PyTorch                        0       0         0                25
# React                          0       0        14                 0
# Redis                          0       0         0                 0
# SQLite                         0       0         0                 0
# Scikit-learn                  13       0         0                 0
# TensorFlow                     0       0         0                 7
# Vue                            0       0         8                 0

# %%
df.groupby(
    "categoria"
)["tecnologia"].nunique()
# Out:
# categoria
# Backend             3
# Bases de Datos      6
# Cloud               3
# Cybersecurity       3
# Data Science        3
# DevOps              3
# Frontend            3
# Machine Learning    3
# Name: tecnologia, dtype: int64

# %% [markdown]
# Inspeccionando titulo por categoria

# %%
df.groupby("categoria")["texto"].apply(
    lambda x: " ".join(x)
).str.lower().str.split().str[:30]
# Out:
# categoria
# Backend             [fastapi, -, fastapi, skip, to, content, fasta...
# Bases de Datos      [postgresql:, documentation, july, 16,, 2026:,...
# Cloud               [oracle, cloud, portal, build, gen, 2, oracle,...
# Cybersecurity       [owasp, foundation,, the, open, source, founda...
# Data Science        [pandas, documentation, —, pandas, 3.0.4, docu...
# DevOps              [docker, docs, start, a, new, chat, when, enab...
# Frontend            [react, react, the, library, for, web, and, na...
# Machine Learning    [tensorflow, skip, to, main, content, /, engli...
# Name: texto, dtype: object

# %%
for categoria in df["categoria"].unique():
    print("\n" + "=" * 60)
    print(categoria)
    print("=" * 60)

    print(
        df[df["categoria"] == categoria]["titulo"]
        .head(10)
        .to_string(index=False)
    )
# Out:
# ============================================================
# Backend
# ============================================================
# FastAPI - FastAPI Official Docs - Parte 1
# FastAPI - FastAPI Official Docs - Parte 2
# FastAPI - FastAPI Official Docs - Parte 3
# FastAPI - FastAPI Official Docs - Parte 4
# FastAPI - FastAPI Official Docs - Parte 5
# FastAPI - FastAPI Official Docs - Parte 6
# FastAPI - FastAPI Official Docs - Parte 7
#        FastAPI - FastAPI GitHub - Parte 1
#        FastAPI - FastAPI GitHub - Parte 2
#        FastAPI - FastAPI GitHub - Parte 3
#
# ============================================================
# Frontend
# ============================================================
# React - React Official Docs - Parte 1
# React - React Official Docs - Parte 2
# React - React Official Docs - Parte 3
# React - React Official Docs - Parte 4
#        React - React GitHub - Parte 1
#        React - React GitHub - Parte 2
#        React - React GitHub - Parte 3
#      React - React Tutorial - Parte 1
#      React - React Tutorial - Parte 2
#      React - React Tutorial - Parte 3
#
# ============================================================
# Data Science
# ============================================================
# Pandas - Pandas Official Docs - Parte 1
#        Pandas - Pandas GitHub - Parte 1
#        Pandas - Pandas GitHub - Parte 2
#        Pandas - Pandas GitHub - Parte 3
#        Pandas - Pandas GitHub - Parte 4
#      Pandas - Pandas Tutorial - Parte 1
#      Pandas - Pandas Tutorial - Parte 2
#      Pandas - Pandas Tutorial - Parte 3
#      Pandas - Pandas Tutorial - Parte 4
#   NumPy - NumPy Official Docs - Parte 1
#
# ============================================================
# Machine Learning
# ============================================================
# TensorFlow - TensorFlow Official Docs - Parte 1
# TensorFlow - TensorFlow Official Docs - Parte 2
#        TensorFlow - TensorFlow GitHub - Parte 1
#        TensorFlow - TensorFlow GitHub - Parte 2
#        TensorFlow - TensorFlow GitHub - Parte 3
#      TensorFlow - TensorFlow Tutorial - Parte 1
#      TensorFlow - TensorFlow Tutorial - Parte 2
#       PyTorch - PyTorch Official Docs - Parte 1
#       PyTorch - PyTorch Official Docs - Parte 2
#       PyTorch - PyTorch Official Docs - Parte 3
#
# ============================================================
# DevOps
# ============================================================
#            Docker - Docker Official Docs - Parte 1
#                   Docker - Docker GitHub - Parte 1
#                   Docker - Docker GitHub - Parte 2
#                   Docker - Docker GitHub - Parte 3
#                 Docker - Docker Tutorial - Parte 1
#    Kubernetes - Kubernetes Official Docs - Parte 1
#           Kubernetes - Kubernetes GitHub - Parte 1
#           Kubernetes - Kubernetes GitHub - Parte 2
#         Kubernetes - Kubernetes Tutorial - Parte 1
# GitHub Actions - GitHub Actions Official Docs -...
#
# ============================================================
# Cloud
# ============================================================
# Oracle Cloud (OCI) - Oracle Cloud (OCI) Officia...
# Oracle Cloud (OCI) - Oracle Cloud (OCI) GitHub ...
# Oracle Cloud (OCI) - Oracle Cloud (OCI) GitHub ...
# Oracle Cloud (OCI) - Oracle Cloud (OCI) GitHub ...
# Oracle Cloud (OCI) - Oracle Cloud (OCI) GitHub ...
# Oracle Cloud (OCI) - Oracle Cloud (OCI) Tutoria...
# Oracle Cloud (OCI) - Oracle Cloud (OCI) Tutoria...
# Oracle Cloud (OCI) - Oracle Cloud (OCI) Tutoria...
# Oracle Cloud (OCI) - Oracle Cloud (OCI) Tutoria...
# Oracle Cloud (OCI) - Oracle Cloud (OCI) Tutoria...
#
# ============================================================
# Bases de Datos
# ============================================================
# PostgreSQL - PostgreSQL Official Docs - Parte 1
#        PostgreSQL - PostgreSQL GitHub - Parte 1
#        PostgreSQL - PostgreSQL GitHub - Parte 2
#      PostgreSQL - PostgreSQL Tutorial - Parte 1
#                  MySQL - MySQL GitHub - Parte 1
#                  MySQL - MySQL GitHub - Parte 2
#       MongoDB - MongoDB Official Docs - Parte 1
#       MongoDB - MongoDB Official Docs - Parte 2
#              MongoDB - MongoDB GitHub - Parte 1
#              MongoDB - MongoDB GitHub - Parte 2
#
# ============================================================
# Cybersecurity
# ============================================================
# OWASP - OWASP Official Docs - Parte 1
# OWASP - OWASP Official Docs - Parte 2
#        OWASP - OWASP GitHub - Parte 1
#        OWASP - OWASP GitHub - Parte 2
#        OWASP - OWASP GitHub - Parte 3
#      OWASP - OWASP Tutorial - Parte 1
#      OWASP - OWASP Tutorial - Parte 2
#      OWASP - OWASP Tutorial - Parte 3
#      OWASP - OWASP Tutorial - Parte 4
#      OWASP - OWASP Tutorial - Parte 5

# %% [markdown]
# Creando columna de fuentes

# %%
df["fuente"] = (
    df["titulo"]
    .str.split(" - ")
    .str[1]
)

# %%
df["tecnologia"] = (
    df["titulo"]
    .str.split(" - ")
    .str[0]
)

# %%
df["parte"] = (
    df["titulo"]
    .str.extract(r"Parte (\d+)")
    .astype(int)
)

# %%
df[
    [
        "titulo",
        "tecnologia",
        "fuente",
        "parte",
        "categoria"
    ]
].head(15)
# Out:
#                                        titulo tecnologia  \
# 0   FastAPI - FastAPI Official Docs - Parte 1    FastAPI
# 1   FastAPI - FastAPI Official Docs - Parte 2    FastAPI
# 2   FastAPI - FastAPI Official Docs - Parte 3    FastAPI
# 3   FastAPI - FastAPI Official Docs - Parte 4    FastAPI
# 4   FastAPI - FastAPI Official Docs - Parte 5    FastAPI
# 5   FastAPI - FastAPI Official Docs - Parte 6    FastAPI
# 6   FastAPI - FastAPI Official Docs - Parte 7    FastAPI
# 7          FastAPI - FastAPI GitHub - Parte 1    FastAPI
# 8          FastAPI - FastAPI GitHub - Parte 2    FastAPI
# 9          FastAPI - FastAPI GitHub - Parte 3    FastAPI
# 10         FastAPI - FastAPI GitHub - Parte 4    FastAPI
# 11         FastAPI - FastAPI GitHub - Parte 5    FastAPI
# 12         FastAPI - FastAPI GitHub - Parte 6    FastAPI
# 13         FastAPI - FastAPI GitHub - Parte 7    FastAPI
# 14         FastAPI - FastAPI GitHub - Parte 8    FastAPI
#
#                    fuente  parte categoria
# 0   FastAPI Official Docs      1   Backend
# 1   FastAPI Official Docs      2   Backend
# 2   FastAPI Official Docs      3   Backend
# 3   FastAPI Official Docs      4   Backend
# 4   FastAPI Official Docs      5   Backend
# 5   FastAPI Official Docs      6   Backend
# 6   FastAPI Official Docs      7   Backend
# 7          FastAPI GitHub      1   Backend
# 8          FastAPI GitHub      2   Backend
# 9          FastAPI GitHub      3   Backend
# 10         FastAPI GitHub      4   Backend
# 11         FastAPI GitHub      5   Backend
# 12         FastAPI GitHub      6   Backend
# 13         FastAPI GitHub      7   Backend
# 14         FastAPI GitHub      8   Backend

# %% [markdown]
# crear el texto de entrenamiento, para el primer modelo, vamos a combinar el título y el contenido

# %%
df["texto_modelo"] = (
    df["titulo"].fillna("")
    + " "
    + df["texto"].fillna("")
)

# %%
df[
    ["titulo", "texto_modelo", "categoria"]
].head(2)
# Out:
#                                       titulo  \
# 0  FastAPI - FastAPI Official Docs - Parte 1
# 1  FastAPI - FastAPI Official Docs - Parte 2
#
#                                         texto_modelo categoria
# 0  FastAPI - FastAPI Official Docs - Parte 1 Fast...   Backend
# 1  FastAPI - FastAPI Official Docs - Parte 2 woul...   Backend

# %% [markdown]
# 1: separar datos de entrenamiento y prueba

# %%
from sklearn.model_selection import train_test_split

X = df["texto_modelo"]
y = df["categoria"]

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Registros de entrenamiento:", len(X_train))
print("Registros de prueba:", len(X_test))
# Out:
# Registros de entrenamiento: 240
# Registros de prueba: 61

# %%
import sys

print(sys.executable)
# Out:
# C:\Proyectos\TechMind-DS\.venv\Scripts\python.exe

# %%
import sys
# !{sys.executable} -m pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\proyectos\techmind-ds\.venv\lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\proyectos\techmind-ds\.venv\lib\site-packages (from scikit-learn) (2.5.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\proyectos\techmind-ds\.venv\lib\site-packages (from scikit-learn) (1.18.0)
# Requirement already satisfied: joblib>=1.4.0 in c:\proyectos\techmind-ds\.venv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\proyectos\techmind-ds\.venv\lib\site-packages (from scikit-learn) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\proyectos\techmind-ds\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# 2: transformar el texto con TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(
    lowercase=True,
    max_features=5000,
    ngram_range=(1, 2),
    min_df=2
)

X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

print("Forma de X_train:", X_train_tfidf.shape)
print("Forma de X_test:", X_test_tfidf.shape)
# Out:
# Forma de X_train: (240, 5000)
# Forma de X_test: (61, 5000)

# %% [markdown]
# 3: entrenar el primer modelo

# %%
from sklearn.linear_model import LogisticRegression

modelo = LogisticRegression(
    max_iter=1000,
    class_weight="balanced",
    random_state=42
)

modelo.fit(
    X_train_tfidf,
    y_train
)

print("Modelo entrenado correctamente")
# Out:
# Modelo entrenado correctamente

# %% [markdown]
# 4: Prediccion

# %%
y_pred = modelo.predict(X_test_tfidf)

print(y_pred[:10])
# Out:
# ['Frontend' 'Bases de Datos' 'Cybersecurity' 'Bases de Datos' 'Backend'
#  'Backend' 'Machine Learning' 'Backend' 'Bases de Datos' 'Cybersecurity']

# %% [markdown]
# Matricas

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(
    y_test,
    y_pred
)

print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.8852

# %%
from sklearn.metrics import classification_report

print(
    classification_report(
        y_test,
        y_pred
    )
)
# Out:
#                   precision    recall  f1-score   support
#
#          Backend       1.00      0.71      0.83         7
#   Bases de Datos       1.00      0.87      0.93        15
#            Cloud       0.93      0.93      0.93        14
#    Cybersecurity       0.50      0.75      0.60         4
#     Data Science       1.00      1.00      1.00         5
#           DevOps       0.60      1.00      0.75         3
#         Frontend       0.83      1.00      0.91         5
# Machine Learning       1.00      0.88      0.93         8
#
#         accuracy                           0.89        61
#        macro avg       0.86      0.89      0.86        61
#     weighted avg       0.92      0.89      0.89        61

# %% [markdown]
# Que casos confunden al modelo actualmente, Matriz de confucion para indicar los errores

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd

cm = confusion_matrix(
    y_test,
    y_pred,
    labels=modelo.classes_
)

cm_df = pd.DataFrame(
    cm,
    index=modelo.classes_,
    columns=modelo.classes_
)

cm_df
# Out:
#                   Backend  Bases de Datos  Cloud  Cybersecurity  Data Science  \
# Backend                 5               0      0              1             0
# Bases de Datos          0              13      0              1             0
# Cloud                   0               0     13              1             0
# Cybersecurity           0               0      1              3             0
# Data Science            0               0      0              0             5
# DevOps                  0               0      0              0             0
# Frontend                0               0      0              0             0
# Machine Learning        0               0      0              0             0
#
#                   DevOps  Frontend  Machine Learning
# Backend                0         1                 0
# Bases de Datos         1         0                 0
# Cloud                  0         0                 0
# Cybersecurity          0         0                 0
# Data Science           0         0                 0
# DevOps                 3         0                 0
# Frontend               0         5                 0
# Machine Learning       1         0                 7

# %%
errores = df.loc[
    X_test.index[y_test != y_pred],
    [
        "titulo",
        "tecnologia",
        "categoria",
        "texto"
    ]
].copy()

errores["prediccion"] = y_pred[y_test != y_pred]

errores[
    [
        "titulo",
        "tecnologia",
        "categoria",
        "prediccion"
    ]
]
# Out:
#                                                 titulo          tecnologia  \
# 25                    Django - Django GitHub - Parte 3              Django
# 124       Hugging Face - Hugging Face GitHub - Parte 2        Hugging Face
# 210           PostgreSQL - PostgreSQL GitHub - Parte 2          PostgreSQL
# 237    Kali Linux - Kali Linux Official Docs - Parte 1          Kali Linux
# 216                 MongoDB - MongoDB GitHub - Parte 1             MongoDB
# 143  Oracle Cloud (OCI) - Oracle Cloud (OCI) GitHub...  Oracle Cloud (OCI)
# 34                    NestJS - NestJS GitHub - Parte 3              NestJS
#
#             categoria     prediccion
# 25            Backend  Cybersecurity
# 124  Machine Learning         DevOps
# 210    Bases de Datos  Cybersecurity
# 237     Cybersecurity          Cloud
# 216    Bases de Datos         DevOps
# 143             Cloud  Cybersecurity
# 34            Backend       Frontend

# %%
PRUEBA CON UN SEGUNDO MODELO
# Out:
#   Cell In[39], line 1
#     PRUEBA CON UN SEGUNDO MODELO
#            ^
# SyntaxError: invalid syntax

# %%
X_solo_texto = df["texto"].fillna("")

# %%
X_train_texto, X_test_texto, y_train_texto, y_test_texto = train_test_split(
    X_solo_texto,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
vectorizer_texto = TfidfVectorizer(
    lowercase=True,
    max_features=5000,
    ngram_range=(1, 2),
    min_df=2
)

X_train_texto_tfidf = vectorizer_texto.fit_transform(X_train_texto)
X_test_texto_tfidf = vectorizer_texto.transform(X_test_texto)

# %% [markdown]
# ENTRENAMIENTO

# %%
modelo_texto = LogisticRegression(
    max_iter=1000,
    class_weight="balanced",
    random_state=42
)

modelo_texto.fit(
    X_train_texto_tfidf,
    y_train_texto
)

y_pred_texto = modelo_texto.predict(
    X_test_texto_tfidf
)

# %%
from sklearn.metrics import classification_report

print(
    classification_report(
        y_test_texto,
        y_pred_texto
    )
)

# %% [markdown]
# evaluación por tecnología

# %%
tecnologias_por_categoria = (
    df.groupby("categoria")["tecnologia"]
    .unique()
)

tecnologias_por_categoria

# %% [markdown]
# evaluación más equilibrada:

# %%
tecnologias_test = {
    "Backend": ["NestJS"],
    "Bases de Datos": ["SQLite", "MariaDB"],
    "Cloud": ["AWS"],
    "Cybersecurity": ["Kali Linux"],
    "Data Science": ["NumPy"],
    "DevOps": ["GitHub Actions"],
    "Frontend": ["Angular"],
    "Machine Learning": ["Hugging Face"]
}

# %%
creamos una máscara para identificar los registros de prueba:

# %%
mask_test = df.apply(
    lambda fila: fila["tecnologia"]
    in tecnologias_test[fila["categoria"]],
    axis=1
)

# %%
df_test_generalizacion = df[mask_test].copy()
df_train_generalizacion = df[~mask_test].copy()

print(
    "Registros de entrenamiento:",
    len(df_train_generalizacion)
)

print(
    "Registros de prueba:",
    len(df_test_generalizacion)
)

# %%
set(
    df_train_generalizacion["tecnologia"]
).intersection(
    set(df_test_generalizacion["tecnologia"])
)

# %% [markdown]
# preparar los datos

# %%
X_train_gen = (
    df_train_generalizacion["titulo"].fillna("")
    + " "
    + df_train_generalizacion["texto"].fillna("")
)

y_train_gen = df_train_generalizacion["categoria"]

X_test_gen = (
    df_test_generalizacion["titulo"].fillna("")
    + " "
    + df_test_generalizacion["texto"].fillna("")
)

y_test_gen = df_test_generalizacion["categoria"]

# %%
print("Categorías en entrenamiento:")
print(y_train_gen.value_counts())

print("\nCategorías en prueba:")
print(y_test_gen.value_counts())

# %% [markdown]
# 1: TF-IDF para generalización

# %%
vectorizer_gen = TfidfVectorizer(
    lowercase=True,
    max_features=5000,
    ngram_range=(1, 2),
    min_df=2
)

X_train_gen_tfidf = vectorizer_gen.fit_transform(X_train_gen)
X_test_gen_tfidf = vectorizer_gen.transform(X_test_gen)

print("Forma de entrenamiento:", X_train_gen_tfidf.shape)
print("Forma de prueba:", X_test_gen_tfidf.shape)

# %% [markdown]
# 2: entrenar el modelo

# %%
modelo_gen = LogisticRegression(
    max_iter=1000,
    class_weight="balanced",
    random_state=42
)

modelo_gen.fit(
    X_train_gen_tfidf,
    y_train_gen
)

print("Modelo de generalización entrenado")

# %%
y_pred_gen = modelo_gen.predict(
    X_test_gen_tfidf
)

print(y_pred_gen[:10])

# %%
accuracy_gen = accuracy_score(
    y_test_gen,
    y_pred_gen
)

print(
    f"Accuracy generalización: {accuracy_gen:.4f}"
)

# %%
print(
    classification_report(
        y_test_gen,
        y_pred_gen
    )
)

# %% [markdown]
# distribuyen las predicciones de la evaluación de generalización:

# %%
pd.Series(y_pred_gen).value_counts()

# %% [markdown]
# Evaluación por documento original

# %%
df.groupby(
    ["categoria", "tecnologia", "fuente"]
).size()

# %%
df["fuente"].nunique()

# %% [markdown]
# Vamos a dividir por fuente completa.

# %%
fuentes_por_categoria = (
    df.groupby("categoria")["fuente"]
    .nunique()
    .sort_values()
)

fuentes_por_categoria

# %%
df.groupby(
    ["categoria", "fuente"]
).size()

# %% [markdown]
# evaluacion, 1: crear la división por fuente

# %%
import numpy as np

np.random.seed(42)

fuentes_train = []
fuentes_test = []

for categoria, grupo in df.groupby("categoria"):
    
    fuentes = grupo["fuente"].unique().tolist()
    
    np.random.shuffle(fuentes)
    
    n_test = max(2, round(len(fuentes) * 0.30))
    
    fuentes_test_categoria = fuentes[:n_test]
    fuentes_train_categoria = fuentes[n_test:]
    
    fuentes_test.extend(fuentes_test_categoria)
    fuentes_train.extend(fuentes_train_categoria)

print("Fuentes de entrenamiento:", len(fuentes_train))
print("Fuentes de prueba:", len(fuentes_test))

# %% [markdown]
# 2: crear los datasets

# %%
df_train_fuente = df[
    df["fuente"].isin(fuentes_train)
].copy()

df_test_fuente = df[
    df["fuente"].isin(fuentes_test)
].copy()

print("Registros de entrenamiento:", len(df_train_fuente))
print("Registros de prueba:", len(df_test_fuente))

# %% [markdown]
# 3: verificar que no hay fuga de información

# %%
interseccion_fuentes = set(
    df_train_fuente["fuente"]
).intersection(
    set(df_test_fuente["fuente"])
)

print(interseccion_fuentes)

# %% [markdown]
# 4: revisar el balance

# %%
print("TRAIN")
print(
    df_train_fuente["categoria"].value_counts()
)

print("\nTEST")
print(
    df_test_fuente["categoria"].value_counts()
)

# %%
print("FUENTES TRAIN POR CATEGORÍA")
print(
    df_train_fuente.groupby("categoria")["fuente"]
    .nunique()
)

print("\nFUENTES TEST POR CATEGORÍA")
print(
    df_test_fuente.groupby("categoria")["fuente"]
    .nunique()
)

# %% [markdown]
# vamos a balancear

# %%
df.groupby(
    ["categoria", "tecnologia"]
).size().sort_values()

# %% [markdown]
# Tabla de control

# %%
objetivo = 40

resumen_balance = (
    df["categoria"]
    .value_counts()
    .rename("actual")
    .to_frame()
)

resumen_balance["objetivo"] = objetivo

resumen_balance["faltan"] = (
    resumen_balance["objetivo"]
    - resumen_balance["actual"]
).clip(lower=0)

resumen_balance.sort_values("actual")

# %% [markdown]
# plan de nuevas fuentes

# %%
plan_nuevas_tecnologias = pd.DataFrame({
    "categoria": [
        "DevOps", "DevOps", "DevOps", "DevOps",
        "Cybersecurity", "Cybersecurity", "Cybersecurity", "Cybersecurity",
        "Frontend", "Frontend", "Frontend",
        "Data Science", "Data Science", "Data Science",
        "Backend",
        "Machine Learning"
    ],
    "tecnologia": [
        "Jenkins", "Terraform", "Ansible", "GitLab CI/CD",
        "Wireshark", "Metasploit", "MITRE ATT&CK", "Burp Suite",
        "Next.js", "Svelte", "Astro",
        "Matplotlib", "SciPy", "Jupyter",
        "Express.js",
        "XGBoost"
    ]
})

plan_nuevas_tecnologias

# %%
df_topics = pd.read_csv(
    "../data/external/topics.csv"
)

df_topics.tail(20)

# %%
topics = pd.read_csv(
    r"C:\Proyectos\TechMind-DS\data\external\topics.csv"
)

print(topics.shape)
print(topics.columns.tolist())
print(topics.tail(20))

# %%
topics.groupby("categoria")["tecnologia"].nunique()

# %%
LIMPIANDO NUESTRO DATASET

# %%
topics.columns = topics.columns.str.strip()

# Eliminar duplicados por categoría y tecnología
topics = topics.drop_duplicates(
    subset=["categoria", "tecnologia"],
    keep="first"
)

# Corregir URL de AWS
topics.loc[
    topics["tecnologia"] == "AWS",
    "tutorial"
] = "https://aws.amazon.com/getting-started/"

print("Tecnologías únicas:", topics["tecnologia"].nunique())
print(topics.groupby("categoria")["tecnologia"].nunique())

# %% [markdown]
# AGREGANDO NUEVAS TECNOLOGIAS PARA BALANCEAR

# %%
nuevas_tecnologias = pd.DataFrame({
    "id": range(
        topics["id"].max() + 1,
        topics["id"].max() + 17
    ),
    "categoria": [
        "DevOps", "DevOps", "DevOps", "DevOps",
        "Cybersecurity", "Cybersecurity", "Cybersecurity", "Cybersecurity",
        "Frontend", "Frontend", "Frontend",
        "Data Science", "Data Science", "Data Science",
        "Backend",
        "Machine Learning"
    ],
    "tecnologia": [
        "Jenkins", "Terraform", "Ansible", "GitLab CI/CD",
        "Wireshark", "Metasploit", "MITRE ATT&CK", "Burp Suite",
        "Next.js", "Svelte", "Astro",
        "Matplotlib", "SciPy", "Jupyter",
        "Express.js",
        "XGBoost"
    ],
    "sitio_oficial": [
        "https://www.jenkins.io/doc/",
        "https://developer.hashicorp.com/terraform/docs",
        "https://docs.ansible.com/",
        "https://docs.gitlab.com/ee/ci/",
        "https://www.wireshark.org/docs/",
        "https://docs.metasploit.com/",
        "https://attack.mitre.org/",
        "https://portswigger.net/burp/documentation",
        "https://nextjs.org/docs",
        "https://svelte.dev/docs",
        "https://docs.astro.build/",
        "https://matplotlib.org/stable/",
        "https://docs.scipy.org/doc/scipy/",
        "https://jupyter.org/documentation",
        "https://expressjs.com/",
        "https://xgboost.readthedocs.io/"
    ],
    "github": [
        "https://github.com/jenkinsci/jenkins",
        "https://github.com/hashicorp/terraform",
        "https://github.com/ansible/ansible",
        "https://gitlab.com/gitlab-org/gitlab",
        "https://github.com/wireshark/wireshark",
        "https://github.com/rapid7/metasploit-framework",
        "https://github.com/mitre-attack/attack-stix-data",
        "https://github.com/PortSwigger",
        "https://github.com/vercel/next.js",
        "https://github.com/sveltejs/svelte",
        "https://github.com/withastro/astro",
        "https://github.com/matplotlib/matplotlib",
        "https://github.com/scipy/scipy",
        "https://github.com/jupyter/notebook",
        "https://github.com/expressjs/express",
        "https://github.com/dmlc/xgboost"
    ],
    "tutorial": [
        "https://www.jenkins.io/doc/tutorials/",
        "https://developer.hashicorp.com/terraform/tutorials",
        "https://docs.ansible.com/ansible/latest/getting_started/",
        "https://docs.gitlab.com/ee/ci/quick_start/",
        "https://www.wireshark.org/docs/wsug_html_chunked/",
        "https://docs.metasploit.com/",
        "https://attack.mitre.org/resources/",
        "https://portswigger.net/web-security",
        "https://nextjs.org/learn",
        "https://svelte.dev/tutorial/",
        "https://docs.astro.build/en/tutorial/",
        "https://matplotlib.org/stable/tutorials/",
        "https://docs.scipy.org/doc/scipy/tutorial/",
        "https://docs.jupyter.org/en/latest/",
        "https://expressjs.com/en/starter/installing.html",
        "https://xgboost.readthedocs.io/en/stable/tutorials/"
    ]
})

nuevas_tecnologias
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 3
#       1 nuevas_tecnologias = pd.DataFrame({
#       2     "id": range(
# ----> 3         topics["id"].max() + 1,
#       4         topics["id"].max() + 17
#       5     ),
#       6     "categoria": [
#
# NameError: name 'topics' is not defined

# %%
topics_ampliado = pd.concat(
    [topics, nuevas_tecnologias],
    ignore_index=True
)

print("Total de tecnologías:",
      topics_ampliado["tecnologia"].nunique())

print("\nDistribución:")
print(
    topics_ampliado.groupby("categoria")["tecnologia"]
    .nunique()
)

# %% [markdown]
# REMPLAZANDO

# %%
topics_ampliado.to_csv(
    r"C:\Proyectos\TechMind-DS\data\external\topics.csv",
    index=False,
    encoding="utf-8-sig"
)

print(" topics.csv actualizado correctamente")
print(f" Filas: {len(topics_ampliado)}")
print(f" Tecnologías únicas: {topics_ampliado['tecnologia'].nunique()}")

# %%
topics_verificacion = pd.read_csv(
    r"C:\Proyectos\TechMind-DS\data\external\topics.csv"
)

topics_verificacion.columns = topics_verificacion.columns.str.strip()

print(topics_verificacion.shape)
print(topics_verificacion.groupby("categoria")["tecnologia"].nunique())

# %%
import pandas as pd

sources_validated = pd.read_csv(
    r"C:\Proyectos\TechMind-DS\data\external\sources_validated.csv"
)

print(sources_validated.columns.tolist())

# %%
sources_validated[
    sources_validated["accessible"] == False
][
    ["categoria", "tecnologia", "tipo", "url"]
]

# %% [markdown]
# REPARAR FUENTES

# %%
topics_ampliado.loc[
    topics_ampliado["tecnologia"] == "MySQL",
    "sitio_oficial"
] = "https://www.mysql.com/"

topics_ampliado.loc[
    topics_ampliado["tecnologia"] == "MySQL",
    "tutorial"
] = "https://www.mysqltutorial.org/"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 topics_ampliado.loc[
#       2     topics_ampliado["tecnologia"] == "MySQL",
#       3     "sitio_oficial"
#       4 ] = "https://www.mysql.com/"
#
# NameError: name 'topics_ampliado' is not defined

# %%
topics_ampliado.to_csv(
    r"C:\Proyectos\TechMind-DS\data\external\topics.csv",
    index=False,
    encoding="utf-8-sig"
)

# %% [markdown]
# IDENTIFICANDO FUENTES FALSAS

# %%
sources_validated[
    sources_validated["accessible"] == False
][
    ["categoria", "tecnologia", "tipo", "url"]
]

# %%
sources_validated = pd.read_csv(
    r"C:\Proyectos\TechMind-DS\data\external\sources_validated.csv"
)

# %%
# Verificar la última fuente no accesible

sources_validated[
    sources_validated["accessible"] == False
][
    ["categoria", "tecnologia", "tipo", "url"]
]

# %%
import pandas as pd

raw_docs = pd.read_csv(
    r"C:\Proyectos\TechMind-DS\data\raw\raw_documents.csv"
)

print(raw_docs.shape)
print(raw_docs.columns.tolist())
raw_docs.head()

# %%
raw_docs.info()

# %%
raw_docs["categoria"].value_counts()

# %%
raw_docs.groupby(
    ["categoria", "tecnologia"]
).size()

# %%
raw_docs.groupby(
    ["categoria", "tipo"]
).size()

# %%
dataset_old = pd.read_csv(
    r"C:\Proyectos\TechMind-DS\data\processed\dataset.csv"
)

# %%
dataset_old = pd.read_csv(
    r"C:\Proyectos\TechMind-DS\data\processed\dataset.csv"
)

print("Dataset anterior:", dataset_old.shape)
print("Dataset nuevo:", raw_docs.shape)

# %%
dataset_old.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 dataset_old.head()
#
# NameError: name 'dataset_old' is not defined

# %%
raw_docs.head()

# %%
raw_docs["longitud_texto"].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 raw_docs["longitud_texto"].describe()
#
# NameError: name 'raw_docs' is not defined

# %%
raw_docs.groupby("categoria")["longitud_texto"].agg(
    ["count", "mean", "median", "min", "max"]
).round(0)

# %%
raw_docs.sort_values(
    "longitud_texto"
)[
    ["categoria", "tecnologia", "titulo", "longitud_texto"]
].head(15)

# %%
# ============================================
# CONSTRUCCIÓN DEL DATASET FINAL
# ============================================

import pandas as pd
import re

# Copia del dataset nuevo
docs = raw_docs.copy()

# --------------------------------------------
# 1. Limpiar textos
# --------------------------------------------

docs["texto"] = (
    docs["texto"]
    .fillna("")
    .astype(str)
    .str.replace(r"\s+", " ", regex=True)
    .str.strip()
)

# --------------------------------------------
# 2. Eliminar documentos demasiado pequeños
# --------------------------------------------

docs = docs[
    docs["longitud_texto"] >= 1000
].copy()

print("Documentos después del filtro:", len(docs))

# %%
docs[
    ["categoria", "tecnologia", "titulo", "longitud_texto"]
].sort_values("longitud_texto").head(10)

# %%
print("Documentos originales:", len(raw_docs))
print("Documentos después del filtro:", len(docs))

# %%
docs["categoria"].value_counts().sort_index()

# %%
docs.groupby(
    ["categoria", "tecnologia"]
).size()

# %%
# ============================================
# FRAGMENTACIÓN DE DOCUMENTOS
# ============================================

def dividir_texto(texto, tamano=1500, solapamiento=200):
    fragmentos = []

    inicio = 0
    longitud = len(texto)

    while inicio < longitud:
        fin = inicio + tamano

        fragmento = texto[inicio:fin].strip()

        if len(fragmento) >= 500:
            fragmentos.append(fragmento)

        inicio = fin - solapamiento

    return fragmentos

# %%
fragmentos = []

for _, fila in docs.iterrows():

    partes = dividir_texto(
        fila["texto"],
        tamano=1500,
        solapamiento=200
    )

    for i, parte in enumerate(partes, start=1):

        fragmentos.append({
            "titulo": f'{fila["tecnologia"]} - {fila["titulo"]} - Parte {i}',
            "texto": parte,
            "categoria": fila["categoria"],
            "tecnologia": fila["tecnologia"],
            "tipo": fila["tipo"],
            "url": fila["url"]
        })

dataset_nuevo = pd.DataFrame(fragmentos)

print("Fragmentos generados:", len(dataset_nuevo))

# %%
dataset_nuevo.groupby("categoria").size()

# %%
dataset_nuevo.groupby(
    ["categoria", "tecnologia"]
).size()

# %%
# ============================================
# CREAR DATASET FINAL BALANCEADO
# ============================================

N_POR_CATEGORIA = 49

dataset_final = (
    dataset_nuevo
    .groupby("categoria", group_keys=False)
    .apply(
        lambda x: x.sample(
            n=N_POR_CATEGORIA,
            random_state=42
        )
    )
    .reset_index(drop=True)
)

print("Registros finales:", len(dataset_final))

# %%
dataset_final["categoria"].value_counts()

# %%
# Revisar estructura actual
print(dataset_final.shape)
print(dataset_final.columns)
print(dataset_final.index.names)

# %%
# Convertir el índice categoria en columna
dataset_final = dataset_final.reset_index()

# Verificar columnas
print(dataset_final.columns)

# %%
dataset_final["categoria"].value_counts()

# %%
topics.columns.tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 topics.columns.tolist()
#
# NameError: name 'topics' is not defined

# %%
import pandas as pd

# %%
topics = pd.read_csv(
    "../data/external/topics.csv"
)

# %%
topics.columns.tolist()

# %%
topics.columns = topics.columns.str.strip()

# %%
tecnologia_categoria = (
    topics
    .drop_duplicates("tecnologia")
    .set_index("tecnologia")["categoria"]
    .to_dict()
)

dataset_final["categoria"] = dataset_final["tecnologia"].map(
    tecnologia_categoria
)

# %%
print(dataset_final.shape)
print(dataset_final.columns.tolist())
print(dataset_final["categoria"].value_counts())
print("\nCategorías faltantes:")
print(dataset_final["categoria"].isna().sum())

# %%
dataset_final = dataset_final.drop(
    columns=["index"]
)

# %%
dataset_final.columns.tolist()

# %%
dataset_final.to_csv(
    "../data/processed/dataset_final.csv",
    index=False,
    encoding="utf-8"
)

# %%
# Eliminar índice antiguo
dataset_final = dataset_final.drop(
    columns=["index"],
    errors="ignore"
)

# Guardar dataset final
dataset_final.to_csv(
    "../data/processed/dataset_final.csv",
    index=False,
    encoding="utf-8"
)

print(" Dataset final guardado correctamente")
print(" Registros:", len(dataset_final))
print(" Columnas:", dataset_final.columns.tolist())

# %%
dataset_check = pd.read_csv(
    "../data/processed/dataset_final.csv"
)

print(dataset_check.shape)
print(dataset_check["categoria"].value_counts())

# %%
dataset_final = pd.read_csv(
    "../data/processed/dataset_final.csv"
)

print(dataset_final.shape)
print(dataset_final.columns)
print(dataset_final["categoria"].value_counts())
# Out:
# (392, 6)
# Index(['titulo', 'texto', 'tecnologia', 'tipo', 'url', 'categoria'], dtype='str')
# categoria
# Backend             49
# Bases de Datos      49
# Cloud               49
# Cybersecurity       49
# Data Science        49
# DevOps              49
# Frontend            49
# Machine Learning    49
# Name: count, dtype: int64

# %% [markdown]
# # ==========================================
# # ENTRENAMIENTO DEL MODELO FINAL
# # ==========================================

# %% [markdown]
# Paso 1: separar las variables

# %%
# Variable de entrada
X = dataset_final["texto"]

# Variable objetivo
y = dataset_final["categoria"]

print("Registros totales:", len(dataset_final))
print("Variable X:", X.shape)
print("Variable y:", y.shape)
# Out:
# Registros totales: 392
# Variable X: (392,)
# Variable y: (392,)

# %% [markdown]
# vamos a dividir el dataset en entrenamiento y prueba usaremos 80% para entrenar y 20% para evaluar, manteniendo las 8 categorías equilibradas mediante stratify=y.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Registros de entrenamiento:", len(X_train))
print("Registros de prueba:", len(X_test))

print("\nCategorías en entrenamiento:")
print(y_train.value_counts().sort_index())

print("\nCategorías en prueba:")
print(y_test.value_counts().sort_index())
# Out:
# Registros de entrenamiento: 313
# Registros de prueba: 79
#
# Categorías en entrenamiento:
# categoria
# Backend             39
# Bases de Datos      40
# Cloud               39
# Cybersecurity       39
# Data Science        39
# DevOps              39
# Frontend            39
# Machine Learning    39
# Name: count, dtype: int64
#
# Categorías en prueba:
# categoria
# Backend             10
# Bases de Datos       9
# Cloud               10
# Cybersecurity       10
# Data Science        10
# DevOps              10
# Frontend            10
# Machine Learning    10
# Name: count, dtype: int64

# %% [markdown]
# TF-IDF transforma las palabras en valores numéricos según su importancia dentro de los documentos.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(
    max_features=5000,
    ngram_range=(1, 2),
    stop_words="english"
)

X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

print("Forma de X_train:", X_train_tfidf.shape)
print("Forma de X_test:", X_test_tfidf.shape)
# Out:
# Forma de X_train: (313, 5000)
# Forma de X_test: (79, 5000)
